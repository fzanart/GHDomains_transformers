# %%
import nltk
import fasttext

class LanguageIdentification:

    def __init__(self):
        pretrained_lang_model = "/tmp/lid.176.bin"
        self.model = fasttext.load_model(pretrained_lang_model)

    def predict_lang(self, text):
        predictions = self.model.predict(text, k=1) # returns top matching language
        return predictions

lang_detector = LanguageIdentification()


def removeHTML(text)
    pass

def clean_text_column(text_column):
    cleaned_html = [removeHTML(text) for text in text_column]
    tokenized_sentences = [nltk.sent_tokenize(text) for text in cleaned_html]
    tokenized_sentences = [sentence.encode("ascii", errors="ignore").decode() for text in tokenized_sentences for sentence in text]
    sentence_language = [lang_detector.predict_lang(sentence) for text in tokenized_sentences for sentence in text]
    sentence_language_count = [len(text) for text in tokenized_sentences]
    sentence_language = [sentence.count('en') for text in tokenized_sentence for sentence in text]
    sentence_language = [eng_lang / count for text in zip(sentence_language, sentence_language_count)]
    clean_sentence = ([' '.join(sentence) for text in tokenized_sentences for sentence in text])

    return clean_sentence, sentence_language
